# %% [markdown]
# <a href="https://colab.research.google.com/github/Govindbit/Algorithm-Lab/blob/main/Lab_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Greedy Knapsack Problem (Fractional)
# In this lab, we explore the Fractional Knapsack Problem, a fundamental optimization problem that demonstrates the Greedy Algorithmic Paradigm.
# We will implement it using greedy selection (based on value-to-weight ratio) and analyze its time and space complexity.

# %% [markdown]
# - Created by Dr. Ajay

# %% [markdown]
# # Problem Definition
# Given a set of
# n
# n items, each with:
# Value vi
# Weight wi
# A knapsack with maximum capacity **W**
#
# Goal: maximize total value that can be put in the knapsack.
# Constraint: You may take fractions of items.
#
# Greedy Strategy:
#
# *  Sort items by decreasing ratio vi/wi
# *  Select items fully until knapsack is full.
# *  Take fraction of the next item if capacity remains.

# %%
def fractional_knapsack(capacity, items):
    """
    Solves the Fractional Knapsack Problem using a greedy approach.

    Args:
        capacity (int or float): The maximum capacity of the knapsack.
        items (list of tuples): A list of items, where each item is a tuple
                                 (value, weight).

    Returns:
        tuple: A tuple containing the maximum total value and a list of
               (item_index, fraction_taken) for each item.
    """
    indexed_items = [(items[i][0], items[i][1], i) for i in range(len(items))]

    indexed_items.sort(key=lambda x: x[0] / x[1], reverse=True)

    total_value = 0
    knapsack_fill = []

    for value, weight, original_index in indexed_items:
        if capacity <= 0:
            break

        if weight <= capacity:
            capacity -= weight
            total_value += value
            knapsack_fill.append((original_index, 1.0))
        else:
            fraction = capacity / weight
            total_value += value * fraction
            knapsack_fill.append((original_index, fraction))
            capacity = 0

    return total_value, knapsack_fill

items = [(60, 10), (100, 20), (120, 30)]
capacity = 50

max_value, filled_items = fractional_knapsack(capacity, items)

print(f"Maximum value in knapsack: {max_value}")
print("Items taken (original_index, fraction_taken):")
for item_idx, fraction in filled_items:
    print(f"  Item {item_idx}: {fraction:.2f} of item")


items2 = [(10, 2), (5, 3), (15, 5), (7, 7), (6, 1), (18, 4), (3, 1)]
capacity2 = 15
max_value2, filled_items2 = fractional_knapsack(capacity2, items2)

print(f"\nMaximum value in knapsack (Example 2): {max_value2}")
print("Items taken (original_index, fraction_taken) (Example 2):")
for item_idx, fraction in filled_items2:
    print(f"  Item {item_idx}: {fraction:.2f} of item")
# Out:
# Maximum value in knapsack: 240.0
# Items taken (original_index, fraction_taken):
#   Item 0: 1.00 of item
#   Item 1: 1.00 of item
#   Item 2: 0.67 of item
#
# Maximum value in knapsack (Example 2): 55.333333333333336
# Items taken (original_index, fraction_taken) (Example 2):
#   Item 4: 1.00 of item
#   Item 0: 1.00 of item
#   Item 5: 1.00 of item
#   Item 2: 1.00 of item
#   Item 6: 1.00 of item
#   Item 1: 0.67 of item

# %% [markdown]
# In this lab, we implement Huffman Coding, a greedy algorithm used for lossless data compression.
# It assigns variable-length binary codes to input symbols based on their frequencies, ensuring that more frequent symbols receive shorter codes and less frequent symbols receive longer codes.
#
# This algorithm constructs a binary tree (Huffman Tree) where each leaf node represents a character, and the path from the root to a leaf gives the character’s binary code.
#
# Use:
# Huffman Tree Construction using a Min-Priority Queue (Min-Heap).
# Code generation for each character.
# Encoding and decoding using the generated Huffman codes.
# Complexity analysis and comparison with fixed-length encoding.
#
# # Pseudocode:
# 1. Create a leaf node for each character and insert all nodes into a
# 2. min-heap by frequency.
#    *  While the heap has more than one node:
#    * Extract two nodes with the lowest frequencies.
#    * Create a new internal node with frequency = sum of the two.
#    *  Set the two extracted nodes as left and right children.
#    *  Insert the new node back into the min-heap.
# 3. The remaining node is the root of the Huffman Tree.
#
# 4. Traverse the tree:
#    * Assign 0 for left edge and 1 for right edge.
#    * The resulting paths from root to leaves give Huffman codes.

# %%
# write code for above
